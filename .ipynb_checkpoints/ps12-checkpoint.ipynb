# %% [markdown]
# # Наука о данных
# *И. В. Щуров, НИУ ВШЭ*
#
# На [странице курса](http://math-info.hse.ru/s20/i) находятся дополнительные материалы.
#
# ### Домашнее задание №12
#
# *Автор задания Анна Денисова.*
#
# За домашнее задание всего можно набрать <b>25 баллов</b>, хотя для получения полного балла достаточно набрать 20 баллов. Однако, в отличие от предыдущих заданий, баллы, набранные сверх 20, также будут учтены (то есть можно набрать «больше максимума», и в итоге получить больше 10 баллов за курс).
#
# Сейчас мы решим практическую задачу, касающуюся работы с геоданными, чтобы было понятно, где это вообще может пригодиться. Для начала скачаем данные для задания. Перейдите по <a href = 'https://mydata.biz/ru/catalog/databases/borders_ru'>ссылке</a> и скачайте архив, который содержит полигоны (так мы будем называть многоугольники в координатах земной поверхности) административно-территориальных единиц по всей России в формате GeoJSON. Из данного архива вам понадобится файл <i>admin_level_8.geojson</i>.
#
# Давайте посмотрим, что он в себе содержит:

# %%
import json

with open('admin_level_8.geojson', encoding = 'utf-8') as f:
    a = json.load(f)
    
type(a)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c39e62f6e439> in <module>
#       1 import json
#       2
# ----> 3 with open('admin_level_8.geojson', encoding = 'utf-8') as f:
#       4     a = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'admin_level_8.geojson'

# %%
a.keys()
# Out:
# dict_keys(['type', 'geocoding', 'features'])

# %% [markdown]
# Как понятно из названия, формат GeoJSON представляет геоданные в виде JSON-файла. Сами полигоны представлены списком, который хранится по ключу `"features"`. Давайте посмотрим на первый элемент этого списка:

# %%
a['features'][0]
# Out:
# {'id': 3006941,
#  'osm_type': 'relation',
#  'type': 'Feature',
#  'name': 'Весёловский сельский совет',
#  'properties': {'name': 'Весёловский сельский совет',
#   'name:ru': 'Весёловский сельский совет',
#   'name:uk': 'Веселівська сільська рада',
#   'boundary': 'administrative',
#   'wikipedia': 'ru:Весёловский сельский совет (Судакский горсовет)',
#   'admin_level': '8',
#   'is_in:country_code': 'UA'},
#  'geometry': {'type': 'MultiPolygon',
#   'coordinates': [[[[34.88666129999999, 44.849171],
#      [34.88464509999999, 44.8487885],
#      [34.88324939999999, 44.8485237],
#      [34.8796451, 44.8482],
#      [34.8759688, 44.8482171],
#      [34.8719533, 44.84973290000001],
#      [34.8725256, 44.854002099999995],
#      [34.8745288, 44.8584032],
#      [34.877469999999995, 44.859919999999995],
#      [34.87811210000001, 44.862645300000004],
#      [34.8794185, 44.86261880000001],
#      [34.883735900000005, 44.861242999999995],
#      [34.8852, 44.85923999999999],
# ...

# %% [markdown]
# Мы видим, что данный элемент имеет тип *Multipolygon*, то есть какое-то объединение полигонов, однако фактически это обычный полигон. Как так получилось? По сути, это список полигонов, состоящий из одного элемента. Разработчики выбранной базы данных скорее всего сделали это, чтобы привести данные к единому формату. Преобразуем этот список координат в объект `Polygon` из библиотеки `shapely`.

# %%
from shapely.geometry import Polygon

poly = Polygon(a['features'][0]['geometry']['coordinates'][0][0]) 
## Мы берем первый элемент из списка полигонов
poly

# %% [markdown]
# Давайте также на всякий случай проверим, что внутри нашего файла только объекты типа Multipolygon:

# %%
arr = []
for i in range(len(a['features'])):
    arr.append(a['features'][i]['geometry']['type'])

print(set(arr))
# Out:
# {'MultiPolygon'}

# %% [markdown]
# <b>(Задание 1: 0.5 балла)</b> У каждого полигона есть центр. Получите координаты центра полигона выше с помощью метода `.centroid`. Выведите широту и долготу численно.

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
list(poly.centroid.coords)
# Out:
# [(34.87956370078355, 44.854417640805515)]

# %% [markdown]
# <b>(Задание 2: 0.5 балла)</b> Для наших последующих целей нам понадобятся только те полигоны, центроиды которых лежат в центральных районах Москвы. Импортируйте файл [Полигон Москвы.geojson](https://gist.github.com/b1d7056220ab570c00a4c8347fc3bcf1) так же, как мы импортировали <i>admin_level_8.geojson</i>. В этом файле лежит единственный полигон (список features имеет длину 1). Вытащите из GeoJSON-файла координаты единственного лежащего в нем полигона, преобразуйте в `Polygon` и сохраните в переменную `moscow_poly`. Обратите внимание, что теперь вам придется работать не с форматом *Multipolygon*, а с форматом *Polygon*, поэтому вам не нужно будет опускаться в рамках списка координат на уровень ниже (нужно брать не `a['features'][0]['geometry']['coordinates'][0][0]`, а `a['features'][0]['geometry']['coordinates'][0]`).

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿

with open('Полигон Москвы.geojson', encoding = 'utf-8') as f:
    b = json.load(f)

moscow_poly = Polygon(b['features'][0]['geometry']['coordinates'][0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-405c1ce1e186> in <module>
#       1 # YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
#       2
# ----> 3 with open('Полигон Москвы.geojson', encoding = 'utf-8') as f:
#       4     b = json.load(f)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Полигон Москвы.geojson'

# %% [markdown]
# <b>(Задание 3: 2 балла)</b> Создайте датафрейм, колонками которого будут `id` объектов из `a`, их названия, а также широта и долгота центра мультиполигонов из файла <i>admin_level_8.geojson</i>. Назовите датафрейм `df`, а колонки с широтой и долготой — `lat` и `lon` соответственно. Это важно для последующих заданий (задание 5).
#
# <i>Hint:</i> для создания датафрейма необходимо в цикле пройтись по массиву `features` из `a`.

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
import pandas as pd

df = pd.DataFrame(columns = ['id', 'name', 'lon', 'lat'])
for pol in a['features']:
    center = list(Polygon(pol['geometry']['coordinates'][0][0]).centroid.coords)[0]
    df_row = pd.DataFrame({'id':[pol['id']], 'name':[pol['name']], 'lon': [center[0]], 'lat': [center[1]]})
    df = pd.concat([df, df_row])
df.head()
# Out:
#          id                        name        lon        lat
# 0   3006941  Весёловский сельский совет  34.879564  44.854418
# 0   3030949      Табачненский сельсовет  33.676381  44.901384
# 0   3030951         Угловский сельсовет  33.603388  44.820806
# 0   3436418  городское поселение Опочка  28.673126  56.713227
# 0  31001804                    Бугульма  52.797578  54.536056

# %% [markdown]
# <b>(Задание 4: 0.5 балла)</b> Создайте датафрейм из файла с полигоном Москвы. В нем должна быть одна строка и два столбца: в одном название (`"Москва"`), в другом - полигон `moscow_poly`. Назовите датафрейм `df1`, а колонку с полигоном `poly` - это важно для последующих заданий (задание 5).

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
df1 = pd.DataFrame(columns = ['name', 'poly'])
df1.loc[0] = ["Москва", moscow_poly]

# %% [markdown]
# <b>(Задание 5: 3 балла)</b> Мы хотим понять, какие из центров полигонов датафрейма `df` лежат внутри полигона Москвы. Это поможет нам выделить полигоны центральных районов Москвы. Для этого мы воспользуемся функцией библиотеки GeoPandas `sjoin`. Заметим, что `sjoin` работает только для геодатафреймов, поэтому сначала нам нужно создать два геодатафрейма из `df` и `df1`. Посмотрим, как это делается:

# %%
import geopandas as gpd

gdf = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df['lon'], df['lat']))
# при создании геодатафрейма нужно явно указывать, какой столбец содержит информацию
# о геоданных (geometry)
# в случае с gdf мы сказали, что этот столбец нужно создать, используя
# координаты точек, хранящиеся в столбцах `lon` и `lat`

gdf1 = gpd.GeoDataFrame(df1, geometry = 'poly')
# в этом случае мы сказали, что нужно просто взять содержимое столбца `poly`
# в качестве `geometry`

# %%
gdf.head(2)
# Out:
#         id                        name        lon        lat  \
# 0  3006941  Весёловский сельский совет  34.879564  44.854418
# 0  3030949      Табачненский сельсовет  33.676381  44.901384
#
#                     geometry
# 0  POINT (34.87956 44.85442)
# 0  POINT (33.67638 44.90138)

# %%
gdf1.head(2)
# Out:
#      name                                               poly
# 0  Москва  POLYGON ((37.37668 55.79579, 37.36433 55.73152...

# %% [markdown]
# Примените функцию `sjoin` с параметром `op="intersects"` к геодатафреймам выше и создайте геодатафрейм только с теми полигонами, центроиды которых лежат в полигоне Москвы. Прочитайте подробнее о spatial join в [документации](https://geopandas.org/docs/user_guide/mergingdata.html). Обратите внимание на параметр `how` и вспомните пары по SQL. Что вам нужно выбрать: `right/left/inner`?
#
# <i>Hint:</i> специфицировать никакие параметры, кроме `op` и `how`, не нужно.

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
gdf_moscow = gpd.sjoin(gdf, gdf1, how = 'inner', op="intersects")
gdf_moscow.head()
# Out:
#        id           name_left        lon        lat  \
# 0  446083  Алтуфьевский район  37.583390  55.879769
# 0  446114  район Дорогомилово  37.536823  55.739088
# 0  446080  район Южное Тушино  37.429560  55.842920
# 0  446084     район Лианозово  37.568462  55.900747
# 0  574667       район Вешняки  37.815202  55.730683
#
#                     geometry  index_right name_right
# 0  POINT (37.58339 55.87977)            0     Москва
# 0  POINT (37.53682 55.73909)            0     Москва
# 0  POINT (37.42956 55.84292)            0     Москва
# 0  POINT (37.56846 55.90075)            0     Москва
# 0  POINT (37.81520 55.73068)            0     Москва

# %% [markdown]
# <b>(Задание 6: 2 балла)</b> Выше вы видели пример создания геодатафрейма (задание 5). Создайте датафрейм с колонками `id` (id полигона), `name` (название полигона) и `poly` (геометрическая сущность Polygon, полученная с помощью библиотеки shapely). Преобразуйте данные в геодатафрейм. Возьмите данные из файла <i>admin_level_8.geojson</i>. В геодатафрейме должны быть только полигоны, центроиды которых лежат в полигоне Москвы, их `id` вы должны были получить в предыдущем задании. Обратите внимание, что теперь геометрией должен выступать полигон (параметр `geometry` в GeoDataFrame).

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
ids = []
names = []
polies = []
for pol in a['features']:
    if pol['id'] in list(gdf_moscow['id']):
        ids.append(pol['id'])
        names.append(pol['name'])
        polies.append(Polygon(pol['geometry']['coordinates'][0][0]))
        
d = {'id': ids, 'name': names, 'geometry': polies}
moscow_polies = gpd.GeoDataFrame(d)

# %% [markdown]
# <b>(Задание 7: 1.5 балла)</b> Теперь будет веселое задание по парсингу точек WildBerries, которое показывает, что парсинг далеко не всегда интеллектуальный. Надо спарсить данные по точкам [отсюда](https://www.wildberries.ru/services/besplatnaya-dostavka#terms-delivery). Попробуйте применить функцию `requests.get`, а после просто посмотрите на текст response'а. Вы можете получить данные по точкам, используя только строковые методы.
#
# <i>Hint \#1</i>: Вы можете получить данные по колонкам `workTime`, `id`, `coordinates`, `dtype`, `isExternalPostamat`, `isWb`, `isPost`, `isSortCenter`, `pickupType`, `longitude`, `latitude`, `deliverytype`
#
# <i>Hint \#2</i>: Чтобы преобразовать строку в список со словарями, воспользуйтесь функцией `json.loads()`

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
import requests 
from bs4 import BeautifulSoup
res = requests.get('https://www.wildberries.ru/services/besplatnaya-dostavka#terms-delivery')
soup = BeautifulSoup(res.content)
start_index = res.text.find('pickpoints') + 13
end_index = res.text.find(';\n        var filteredPoos')
data = json.loads(res.text[start_index:end_index])

dtype = [i['dtype'] for i in data]
post_id = [i['id'] for i in data]
latitude = [i['coordinates'][0] for i in data]
longitude = [i['coordinates'][1] for i in data]

postamat_df = pd.DataFrame({'dtype': dtype, 'id': post_id, 'lon': longitude, 'lat': latitude})

# %%
postamat_df['dtype'].unique()
# Out:
# array([ 0,  6, 23])

# %% [markdown]
# <b>(Задание 8: 2 балла)</b> Разбейте столбец с координатами на два столбца с широтой и долготой. В скачанных данных колонка `dtype` кодирует тип доставки, *deliverytype* (это может быть собственный пункт выдачи, т.е. открытый WildBerries/агентский пункт выдачи, т.е. франшиза/Почта РФ и т.п.). Попробуйте понять, что означает тот или иной `dtype`. Для этого зайдите на карту и сравните координаты с тем, что на ней отображается. Создайте отдельную колонку, которая преобразует цифру `dtype` в строковое название типа доставки (например, 'Собственный пункт выдачи').

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
#Я разбил на широту и долготу уже в прошлом задании
#Всего есть 3 dtype - 0,6 и 23
#0 - Пункт выдачи WildBerries
#6 - Партнерский пункт выдачи
#23 - Почта РФ

def change_type(x):
    if x == 0:
        return 'Пункт выдачи WildBerries'
    elif x == 6:
        return 'Партнерский пункт выдачи'
    elif x == 23:
        return 'Почта РФ'
postamat_df['real_type'] = postamat_df['dtype'].apply(change_type)

# %% [markdown]
# <b>(Задание 9: 3 балла)</b> Создайте геодатафрейм, где геометрией выступают координаты точек WildBerries. Примените функцию `sjoin` к данному датафрейму и датафрейму, полученному в задании 6. Удалите из рассмотрения все точки WildBerries, координаты которых лежат не в центральных районах Москвы.

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
postamat_gdf = gpd.GeoDataFrame(postamat_df, geometry = gpd.points_from_xy(postamat_df['lon'], 
                                                                           postamat_df['lat']))
#moscow_postamats = 
moscow_postamats = gpd.sjoin(postamat_gdf, moscow_polies, how = 'right', op="intersects")

# %%
moscow_postamats.head()
# Out:
#    index_left  dtype    id_x        lon        lat                 real_type  \
# 0          13      0   18489  37.587964  55.885014  Пункт выдачи WildBerries
# 0        5105      0   17150  37.578105  55.874730  Пункт выдачи WildBerries
# 0        6552      6  121261  37.579621  55.878970  Партнерский пункт выдачи
# 0        9791      0  113532  37.578374  55.881098  Пункт выдачи WildBerries
# 1        1079      0  105622  37.529054  55.738149  Пункт выдачи WildBerries
#
#      id_y                name  \
# 0  446083  Алтуфьевский район
# 0  446083  Алтуфьевский район
# 0  446083  Алтуфьевский район
# 0  446083  Алтуфьевский район
# 1  446114  район Дорогомилово
#
#                                             geometry
# 0  POLYGON ((37.60716 55.87932, 37.60677 55.87968...
# 0  POLYGON ((37.60716 55.87932, 37.60677 55.87968...
# 0  POLYGON ((37.60716 55.87932, 37.60677 55.87968...
# 0  POLYGON ((37.60716 55.87932, 37.60677 55.87968...
# ...

# %% [markdown]
# <b>(Задание 10: 3 балла)</b> Посмотрите, в каких из центральных районов больше собственных пунктов выдачи / франшизных пунктов выдачи / пунктов выдачи в принципе (не считая Почту РФ). Создайте геодатафрейм, в котором геометрией являются полигоны, и выведите три тепловых карты с помощью библиотеки `matplotlib` (отличие от того, что вы делали на лекции с `adm_moscow`, в том, что теперь надо указать параметр `column`). Как вы думаете, почему тот или иной тип доставки более распространен в одних районах и менее распространен в других?

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
import numpy as np
import matplotlib.pyplot as plt 

data = moscow_postamats[moscow_postamats['dtype'] != 23]
district = list(data.groupby(by = 'name').count().index)
all_posts = list(data.groupby(by = 'name').count()['dtype'])
wildb_posts = list(data[data['real_type']== 'Пункт выдачи WildBerries'].groupby(by = 'name').count()['dtype'])
other_posts = list(np.array(all_posts) - np.array(wildb_posts))
poligons = [data[data['name'] == i]['geometry'].unique()[0] for i in district]

adm_moscow = gpd.GeoDataFrame({'district': district, 'all posts': all_posts, 'wildb posts': wildb_posts, 
                           'other posts': other_posts, 'geometry': poligons})

# %%
adm_moscow.head()
# Out:
#               district  all posts  wildb posts  other posts  \
# 0  Академический район          7            7            0
# 1   Алексеевский район          5            4            1
# 2   Алтуфьевский район          4            3            1
# 3   Бабушкинский район          9            6            3
# 4      Басманный район         13           11            2
#
#                                             geometry
# 0  POLYGON ((37.60149 55.69153, 37.60084 55.69127...
# 1  POLYGON ((37.67046 55.82442, 37.67022 55.82446...
# 2  POLYGON ((37.60716 55.87932, 37.60677 55.87968...
# 3  POLYGON ((37.68354 55.86437, 37.68290 55.86394...
# 4  POLYGON ((37.71333 55.77548, 37.71268 55.77617...

# %%
# %matplotlib inline

# %%
adm_moscow.plot(column = 'all posts') #По всем
# Out:
# <AxesSubplot:>

# %%
adm_moscow.plot(column = 'wildb posts') #По собственным
# Out:
# <AxesSubplot:>

# %%
adm_moscow.plot(column = 'other posts') #По партнерским
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>(Задание 11: 5 баллов)</b> Данное задание взято из домашки по машинному обучению ФКНа и адаптировано под наши цели.
#
# Скачайте файл с данными об остановках общественного транспорта в формате .xlsx по <a href = 'https://data.mos.ru/opendata/download/60464/1/201'>ссылке</a> (так гарантированно не возникнет проблем с парсингом файла) и загрузите таблицу в ноутбук. Если вдруг сайт Правительства Москвы сойдет с ума, то возьмите какую-нибудь версию данных <a href ='https://data.mos.ru/opendata/7704786030-city-surface-public-transport-stops'>отсюда</a>. Для удобства визуализации мы будем работать только с остановками в ЦАО.

# %%
data = pd.read_excel('City surface public transport stops.xlsx')
data = data[data.AdmArea_en == "Czentral`ny'j administrativny'j okrug"]
data = data.reset_index()
data.head()
# Out:
#    index  ID_en                                            Name_en  \
# 0    278    347       «2-й Лесной пер.», улица Бутырский Вал (347)
# 1    279    349    «Ул. Сущевский Вал», Новослободская улица (349)
# 2    355    479  «Стадион Лужники (южн.) (пос.)», улица Лужники...
# 3    356    480      «Спортзал Дружба», Лужнецкая набережная (480)
# 4    357    481       «Лужнецкая наб.», Лужнецкая набережная (481)
#
#    Longitude_WGS84_en  Latitude_WGS84_en             Street_en  \
# 0           37.586584          55.782106   улица Бутырский Вал
# 1           37.590714          55.790630  Новослободская улица
# 2           37.565972          55.714265         улица Лужники
# 3           37.570191          55.712504  Лужнецкая набережная
# 4           37.574559          55.713770  Лужнецкая набережная
#
#                               AdmArea_en      District_en  \
# 0  Czentral`ny'j administrativny'j okrug   Tverskoj rajon
# 1  Czentral`ny'j administrativny'j okrug   Tverskoj rajon
# ...

# %% [markdown]
# Воспользуемся библиотекой folium для визуализации данных:

# %%
import folium

m = folium.Map([55.75215, 37.61819], zoom_start=12)
for ind, row in data.iterrows():
    folium.Circle([row.Latitude_WGS84_en, row.Longitude_WGS84_en],
                  radius=10).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# Как вы уже могли заметить, для каждой остановки указаны номера маршрутов, проходящих через неё. Логично соединить ребрами соседние остановки каждого маршрута. Однако мы не знаем, в каком порядке автобусы объезжают остановки. Но мы можем применить эвристический алгоритм, который восстановит нам порядок маршрутов:
#
# * Для каждого маршрута выделим список всех остановок, через которые он проходит.
# * Выберем начальную остановку маршрута как точку, наиболее удаленную от всех остальных остановок этого маршрута.
# * Каждую следующую точку маршрута будем выбирать как самую близкую из оставшихся точек (не включенных в маршрут ранее).
#
# Реализуйте предложенный способ построения маршрутов. Для этого рекомендуется воспользоваться шаблонами, приведенными ниже.

# %%
def get_routes(data):
    '''
    Accumulate routes from raw data
    param data: pd.DataFrame - public transport stops data
    return: dict - unsorted stops ids for each route,
                   e.g. routes['A1'] = [356, 641, 190]
    '''

    # YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
    routes_dic = {}
    for i in data.index:
        for route in data['RouteNumbers_en'][i].split('; '):
            if route in routes_dic.keys():
                routes_dic[route].append(data['ID_en'][i])
            else:
                routes_dic[route] = [data['ID_en'][i]]
    return routes_dic
    #raise NotImplementedError


def sort_routes(data, routes):
    '''
    Sort routes according to the proposed algorithm
    param data: pd.DataFrame - public transport stops data
    param routes: dict - unsorted stops ids for each route
    return: dict - sorted stops ids for each route
    '''

    # YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
    sorted_routes = {}
    for route in list(routes.keys()):
        matrix = pd.DataFrame(index = routes[route], columns = routes[route])
        for i in matrix.columns:
            for j in matrix.index:
                if i!=j:
                    x = float(data[data['ID_en'] == i]['Longitude_WGS84_en']) - float(data[data['ID_en'] == j]['Longitude_WGS84_en'])
                    y = float(data[data['ID_en'] == i]['Latitude_WGS84_en']) - float(data[data['ID_en'] == j]['Latitude_WGS84_en'])
                    matrix[i][j] = (x**2 + y**2)**0.5
        station = matrix.mean().sort_values(ascending = False).index[0]
        sorted_routes[route] = [station]
        while len(matrix.columns)>1:
            next_station = matrix[station].sort_values().index[0]
            matrix = matrix.drop(station, axis = 0)
            matrix = matrix.drop(station, axis = 1)
            station = next_station
            sorted_routes[route].append(station)
    
    return sorted_routes
    #raise NotImplementedError

# %%
routes = get_routes(data)
sorted_routes = sort_routes(data, routes)

# %% [markdown]
# <b>(Задание 12: 2 балла)</b> Визуализируйте любые 10 из предложенных маршрутов на карте с помощью библиотеки `folium`. Для этого воспользуйтесь методом `folium.vector_layers.PolyLine()`.

# %%
# YOUR CODE HERE ‿︵‿︵ヽ(°□° )ノ︵‿︵‿
m = folium.Map([55.75215, 37.61819], zoom_start=12)
for ind, row in data.iterrows():
    folium.Circle([row.Latitude_WGS84_en, row.Longitude_WGS84_en],
                  radius=10).add_to(m)
    
coordinates1 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['АТ18']]
my_PolyLine1=folium.PolyLine(locations=coordinates1, weight=5)
m.add_child(my_PolyLine1)

coordinates2 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['А144']]
my_PolyLine2=folium.PolyLine(locations=coordinates2,weight=5, color = 'violet')
m.add_child(my_PolyLine2)

coordinates3 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['АТ63']]
my_PolyLine3=folium.PolyLine(locations=coordinates3,weight=5, color = 'white')
m.add_child(my_PolyLine3)

coordinates4 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['А156']]
my_PolyLine4=folium.PolyLine(locations=coordinates4,weight=5, color = 'yellow')
m.add_child(my_PolyLine4)

coordinates5 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['А24']]
my_PolyLine5=folium.PolyLine(locations=coordinates5,weight=5, color = 'brown')
m.add_child(my_PolyLine5)

coordinates6 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['А19']]
my_PolyLine6=folium.PolyLine(locations=coordinates6,weight=5, color = 'black')
m.add_child(my_PolyLine6)

coordinates7 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['А850']]
my_PolyLine7=folium.PolyLine(locations=coordinates7,weight=5, color = 'orange')
m.add_child(my_PolyLine7)

coordinates8 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['АО32']]
my_PolyLine8=folium.PolyLine(locations=coordinates8,weight=5, color = 'green')
m.add_child(my_PolyLine8)

coordinates9 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['АН4']]
my_PolyLine9=folium.PolyLine(locations=coordinates9,weight=5, color = 'pink')
m.add_child(my_PolyLine9)

coordinates10 = [[float(data[data['ID_en'] == i]['Latitude_WGS84_en']), 
               float(data[data['ID_en'] == i]['Longitude_WGS84_en'])] for i in sorted_routes['Тм50']]
my_PolyLine10=folium.PolyLine(locations=coordinates10,weight=5, color = 'red')
m.add_child(my_PolyLine10)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
